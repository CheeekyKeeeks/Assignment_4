# %% [markdown]
# ## Welcome to your notebook.

# %% [markdown]
# #### Run this cell to connect to your GIS and get started:

# %%
from arcgis.gis import GIS
gis = GIS("home")

# %% [markdown]
# #### Now you are ready to start!

# %%
from arcgis.gis import GIS
gis = GIS()

# %%
map1 = gis.map('Rochester, NY')
map1
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-fbfd36e6-0665-45f8-8a22-7c9b090ae61b"><img src=""></img></div>
# <div class="map-html-embed-preview-fbfd36e6-0665-45f8-8a22-7c9b090ae61b"></div>

# %%
# Item Added From Toolbar
# Title: City of Rochester, NY Zoning Districts | Type: Feature Service | Owner: Open_Data_Admin
item = gis.content.get("6a902a35b9004ff6808346b1b2f14d51")
item
# Out:
# <Item title:"City of Rochester, NY Zoning Districts" type:Feature Layer Collection owner:Open_Data_Admin>

# %%
map1.add_layer(item)
